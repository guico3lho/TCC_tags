# %% [markdown]
# ## Packages and Assets

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_pp = pd.read_csv('../assets/data/df_pp.csv')

# remover numeros dos titulos
# df_eda = df_pp.copy()
# df_eda['title'] = df_eda['title'].str.replace(r'\d+', '')
# df_eda
df_pp
# Out:
#                                                    title  \
# 0      dividendos as <NUM> acoes preferidas <NUM> ana...
# 1      itau jhsf banco brasil confira agenda resultad...
# 2      destaques empresas petrobras petr4 jbs jbss3 h...
# 3      itau unibanco itub4 vai pagar proventos comeco...
# 4      petrobras petr4 elege novo conselho maior part...
# ...                                                  ...
# 11951  petrobras guia nova maxima ibovespa sessao meg...
# 11952  petrobras estende vencimento emprestimo banco ...
# 11953  petrobras percepcao risco sobre politica preco...
# 11954  bndes espera vender cerca <NUM> bi debentures ...
# 11955  em ano ruim acoes bancos brasileiros podem sub...
#
#                                                     tags  \
# 0      ['Carteira Recomendada', 'Comprar ou vender?',...
# 1      ['Alper (APER3)', 'balanços trimestrais', 'Bol...
# 2      ['Arezzo (ARZZ3)', 'Cia Hering (HGTX3)', 'dest...
# 3      ['Bancos', 'Dividendos', 'Empresas', 'Itaú Uni...
# 4      ['Ações', 'Adriano Pires', 'Combustíveis', 'Em...
# ...                                                  ...
# 11951  ['Ações', 'Empresas', 'Ibovespa', 'Leilão', 'M...
# 11952                          ['Empresas', 'Petrobras']
# 11953  ['Ações', 'Combustíveis', 'Commodities', 'Comp...
# 11954  ['BNDES', 'BNDESPar', 'debêntures', 'Vale (VAL...
# 11955  ['Ações', 'Banco do Brasil', 'Bancos', 'Brades...
#
#                                                     link  label
# 0      https://www.moneytimes.com.br/dividendos-as-10...      1
# 1      https://www.suno.com.br/noticias/itau-jhsf-ban...      2
# 2      https://www.suno.com.br/noticias/destaques-de-...      0
# 3      https://www.moneytimes.com.br/itau-unibanco-it...      2
# 4      https://www.moneytimes.com.br/petrobras-petr4-...      0
# ...                                                  ...    ...
# 11951  https://www.moneytimes.com.br/petrobras-guia-n...      0
# 11952  https://www.moneytimes.com.br/petrobras-estend...      0
# 11953  https://www.moneytimes.com.br/petrobras-percep...      0
# 11954  https://www.suno.com.br/noticias/bndes-venda-d...      1
# 11955  https://www.moneytimes.com.br/em-ano-ruim-acoe...      2
#
# [11956 rows x 4 columns]

# %%
petr4 = df_pp.loc[df_pp['label'] == 0]
vale3 = df_pp.loc[df_pp['label'] == 1]
itub4 = df_pp.loc[df_pp['label'] == 2]

# %% [markdown]
# ## Functions

# %%
stopwords = ["da", "meu", "em", "voce", "de", "ao", "os", "<NUM>", "<num>", "num", "NUM", 'acoe', 'acoes', 'milhoe',' bilhoe', 'milhoes', 'cento', 'diz', 'bilhoes']

# %%
summary_petr4 = " ".join(str(s) for s in petr4['title'].values)
summary_vale3 = " ".join(str(s) for s in vale3['title'].values)
summary_itub4 = " ".join(str(s) for s in itub4['title'].values)

# %% [markdown]
# ## PETR4

# %% [markdown]
# ### Wordcloud

# %%
wordcloud_petr4 = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_petr4)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_petr4)
plt.axis('off')
plt.title("Words related to PETR4")
plt.show()

# %% [markdown]
# ### See news that doesnt have the word "petrobras" or "petr4"

# %%
petr4
# Out:
#                                                    title  \
# 2      destaques empresas petrobras petr4 jbs jbss3 h...
# 4      petrobras petr4 elege novo conselho maior part...
# 6      com producao junho campo atapu vira <NUM> maio...
# 7      petrobras demite gerente executivo rh claudio ...
# 10     petroleo desaba tira forca etanol ameaca preco...
# ...                                                  ...
# 11946  <NUM> acoes comprar nesta segunda <NUM> segund...
# 11948  petrobras avalia pedido acionistas convocacao ...
# 11951  petrobras guia nova maxima ibovespa sessao meg...
# 11952  petrobras estende vencimento emprestimo banco ...
# 11953  petrobras percepcao risco sobre politica preco...
#
#                                                     tags  \
# 2      ['Arezzo (ARZZ3)', 'Cia Hering (HGTX3)', 'dest...
# 4      ['Ações', 'Adriano Pires', 'Combustíveis', 'Em...
# 6      ['Agência Brasil', 'Commodities', 'Empresas', ...
# 7      ['Empresas', 'Indústria', 'Petrobras', 'Petról...
# 10     ['Açúcar', 'Agronegócio', 'Cana-de-Açúcar', 'E...
# ...                                                  ...
# 11946  ['Ágora Investimentos', 'Alliar', 'Ambev', 'Ca...
# 11948  ['CVM', 'Empresas', 'Mercados', 'Petrobras', '...
# 11951  ['Ações', 'Empresas', 'Ibovespa', 'Leilão', 'M...
# 11952                          ['Empresas', 'Petrobras']
# 11953  ['Ações', 'Combustíveis', 'Commodities', 'Comp...
#
#                                                     link  label
# 2      https://www.suno.com.br/noticias/destaques-de-...      0
# 4      https://www.moneytimes.com.br/petrobras-petr4-...      0
# 6      https://www.moneytimes.com.br/com-producao-de-...      0
# 7      https://www.moneytimes.com.br/petrobras-demite...      0
# 10     https://www.moneytimes.com.br/petroleo-desaba-...      0
# ...                                                  ...    ...
# 11946  https://www.moneytimes.com.br/6-acoes-para-com...      0
# 11948  https://www.moneytimes.com.br/petrobras-avalia...      0
# 11951  https://www.moneytimes.com.br/petrobras-guia-n...      0
# 11952  https://www.moneytimes.com.br/petrobras-estend...      0
# 11953  https://www.moneytimes.com.br/petrobras-percep...      0
#
# [6113 rows x 4 columns]

# %%
petr4.loc[(petr4['title'].str.contains('petrobras') == False) & (petr4['title'].str.contains('petr4') == False)]
# Out:
#                                                    title  \
# 6      com producao junho campo atapu vira <NUM> maio...
# 10     petroleo desaba tira forca etanol ameaca preco...
# 11     marink martins quando derivativos deixam sinto...
# 12                a gasolina vai continuar subindo <NUM>
# 25           grupo monitora abastecimento reune planalto
# ...                                                  ...
# 11893     gasolina diesel baratos refinarias partir hoje
# 11906  cenario vendas fracas fabricas inibe alta etan...
# 11907  fala maia sobre previdencia amplifica perdas i...
# 11921  uniao <NUM> milhoes barris petroleo contratos ...
# 11946  <NUM> acoes comprar nesta segunda <NUM> segund...
#
#                                                     tags  \
# 6      ['Agência Brasil', 'Commodities', 'Empresas', ...
# 10     ['Açúcar', 'Agronegócio', 'Cana-de-Açúcar', 'E...
# 11     ['Comprar ou vender?', 'Inversa', 'Marink Mart...
# 12     ['Combustíveis', 'Consumo', 'Economia', 'Empre...
# 25                             ['Economia', 'Petrobras']
# ...                                                  ...
# 11893  ['Agência Brasil', 'Combustíveis', 'Commoditie...
# 11906  ['Açúcar', 'Agro Times', 'Agronegócio', 'ANP',...
# 11907  ['B2W', 'B3', 'CCR', 'Cemig', 'Ibovespa', 'Mag...
# 11921  ['Agência Brasil', 'Brasil', 'Commodities', 'E...
# 11946  ['Ágora Investimentos', 'Alliar', 'Ambev', 'Ca...
#
#                                                     link  label
# 6      https://www.moneytimes.com.br/com-producao-de-...      0
# 10     https://www.moneytimes.com.br/petroleo-desaba-...      0
# 11     https://www.moneytimes.com.br/marink-martins-q...      0
# 12     https://www.moneytimes.com.br/a-gasolina-vai-c...      0
# 25     https://www.moneytimes.com.br/grupo-que-monito...      0
# ...                                                  ...    ...
# 11893  https://www.moneytimes.com.br/gasolina-e-diese...      0
# 11906  https://www.moneytimes.com.br/cenario-de-venda...      0
# 11907  https://www.moneytimes.com.br/fala-de-maia-sob...      0
# 11921  https://www.moneytimes.com.br/uniao-tem-29-mil...      0
# 11946  https://www.moneytimes.com.br/6-acoes-para-com...      0
#
# [1936 rows x 4 columns]

# %% [markdown]
# ## VALE3

# %% [markdown]
# ### WordCloud

# %%
wordcloud_vale3 = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_vale3)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_vale3)
plt.axis('off')
plt.title("Words related to VALE3")
plt.show()

# %% [markdown]
# ### See news that doesnt have the word "vale" or "vale3"

# %%
vale3
# Out:
#                                                    title  \
# 0      dividendos as <NUM> acoes preferidas <NUM> ana...
# 8      vale vale3 nenhuma barragem estara condicao cr...
# 17     ubs corta vale venda perspectiva excedente min...
# 18       agenda dia vale braskem azul sulamerica embraer
# 21     rio paraopeba niveis metais <NUM> vezes maior ...
# ...                                                  ...
# 11938  analistas <NUM> corretoras elegem melhor acao ...
# 11943  anm diz <NUM> cento barragens montante elabora...
# 11949  vale siderurgicas avancam minerio ferro batend...
# 11950  ubs sete duvidas investidores sobre vale apos ...
# 11954  bndes espera vender cerca <NUM> bi debentures ...
#
#                                                     tags  \
# 0      ['Carteira Recomendada', 'Comprar ou vender?',...
# 8                                       ['Vale (VALE3)']
# 17     ['Aço', 'Ações', 'China', 'Commodities', 'Comp...
# 18     ['agenda do dia', 'Azul', 'AZUL4', 'Braskem (B...
# 21     ['Brumadinho', 'Empresas', 'Meio Ambiente', 'M...
# ...                                                  ...
# 11938  ['Ações', 'Ativa Investimentos', 'Banco Inter'...
# 11943  ['ANM', 'Barragens', 'Brumadinho', 'Empresas',...
# 11949  ['Ações', 'Mercados', 'Mineração', 'Minério de...
# 11950  ['Brumadinho', 'Internacional', 'Investimentos...
# 11954  ['BNDES', 'BNDESPar', 'debêntures', 'Vale (VAL...
#
#                                                     link  label
# 0      https://www.moneytimes.com.br/dividendos-as-10...      1
# 8      https://www.suno.com.br/noticias/vale-vale3-ne...      1
# 17     https://www.moneytimes.com.br/ubs-corta-vale-p...      1
# 18     https://www.suno.com.br/noticias/agenda-do-dia...      1
# 21     https://www.moneytimes.com.br/rio-paraopeba-te...      1
# ...                                                  ...    ...
# 11938  https://www.moneytimes.com.br/analistas-de-8-c...      1
# 11943  https://www.moneytimes.com.br/anm-diz-que-10-d...      1
# 11949  https://www.moneytimes.com.br/vale-e-siderurgi...      1
# 11950  https://www.moneytimes.com.br/ubs-sete-duvidas...      1
# 11954  https://www.suno.com.br/noticias/bndes-venda-d...      1
#
# [3740 rows x 4 columns]

# %%
vale3.loc[(vale3['title'].str.contains('vale3') == False) & (vale3['title'].str.contains('vale') == False)]
# Out:
#                                                    title  \
# 0      dividendos as <NUM> acoes preferidas <NUM> ana...
# 21     rio paraopeba niveis metais <NUM> vezes maior ...
# 51     mp minas gerais recorre stf sobre competencia ...
# 54     cidade mineira vive tensao risco rompimento ba...
# 57     portfolio capital research julho preparado nov...
# ...                                                  ...
# 11901  ibovespa abre semana azul estimulado contexto ...
# 11912  crise eletrica eleva custos parte setor minera...
# 11929  toro troca quatro acoes mantem apenas magazine...
# 11938  analistas <NUM> corretoras elegem melhor acao ...
# 11943  anm diz <NUM> cento barragens montante elabora...
#
#                                                     tags  \
# 0      ['Carteira Recomendada', 'Comprar ou vender?',...
# 21     ['Brumadinho', 'Empresas', 'Meio Ambiente', 'M...
# 51     ['Brumadinho', 'Justiça', 'Justiça Federal', '...
# 54                                  ['Mercados', 'Vale']
# 57     ['Ações', 'Amazon', 'Apple', 'Arezzo', 'Brades...
# ...                                                  ...
# 11901  ['Comissão Parlamentar de Inquérito (CPI)', 'c...
# 11912  ['Anglo American', 'Brasil', 'Energia Elétrica...
# 11929  ['Carteira Recomendada', 'Comprar ou vender?',...
# 11938  ['Ações', 'Ativa Investimentos', 'Banco Inter'...
# 11943  ['ANM', 'Barragens', 'Brumadinho', 'Empresas',...
#
#                                                     link  label
# 0      https://www.moneytimes.com.br/dividendos-as-10...      1
# 21     https://www.moneytimes.com.br/rio-paraopeba-te...      1
# 51     https://www.moneytimes.com.br/mp-de-minas-gera...      1
# 54     https://www.moneytimes.com.br/cidade-mineira-v...      1
# 57     https://www.moneytimes.com.br/portfolio-da-cap...      1
# ...                                                  ...    ...
# 11901  https://www.suno.com.br/noticias/ibovespa-comm...      1
# 11912  https://www.moneytimes.com.br/crise-eletrica-e...      1
# 11929  https://www.moneytimes.com.br/toro-troca-quatr...      1
# 11938  https://www.moneytimes.com.br/analistas-de-8-c...      1
# 11943  https://www.moneytimes.com.br/anm-diz-que-10-d...      1
#
# [1556 rows x 4 columns]

# %% [markdown]
# ## ITUB4

# %% [markdown]
# ### WordCloud

# %%
wordcloud_itub4 = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_itub4)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_itub4)
plt.axis('off')
plt.title("Words related to ITU4")
plt.show()

# %% [markdown]
# ### See news that doesnt have the word "itau" or "itub4"

# %%
itub4
# Out:
#                                                    title  \
# 1      itau jhsf banco brasil confira agenda resultad...
# 3      itau unibanco itub4 vai pagar proventos comeco...
# 5             kroton faz parceria itau startups educacao
# 9      itausa lucro liquido sobe <NUM> cento alcanca ...
# 15     mesquita itau itub4 ve inflacao <NUM> cento <N...
# ...                                                  ...
# 11932  btg espera ganhar clientes agentes negocio xp ...
# 11934  ibovespa opera ganhos perdas sustentado bancos...
# 11942  <NUM> acoes bancos brasileiros melhores ter lo...
# 11947  banco brasil bbas3 itau itub4 veja datas corte...
# 11955  em ano ruim acoes bancos brasileiros podem sub...
#
#                                                     tags  \
# 1      ['Alper (APER3)', 'balanços trimestrais', 'Bol...
# 3      ['Bancos', 'Dividendos', 'Empresas', 'Itaú Uni...
# 5      ['Educação', 'Empresas', 'Itaú Unibanco', 'Kro...
# 9      ['Itaú Unibanco (ITUB3/ITUB4)', 'Itaúsa (ITSA3...
# 15     ['Agências', 'inflação', 'IPCA', 'Itaú Unibanc...
# ...                                                  ...
# 11932  ['Arena do Pavini', 'Bancos', 'BTG Pactual', '...
# 11934  ['Bradesco (BBDC3/BBDC4)', 'Braskem (BRKM3/BRK...
# 11942  ['Ações', 'Banco do Brasil', 'Bancos', 'Brades...
# 11947  ['Eletrobras (ELET3/ELET5/ELET6)', 'Alupar (AL...
# 11955  ['Ações', 'Banco do Brasil', 'Bancos', 'Brades...
#
#                                                     link  label
# 1      https://www.suno.com.br/noticias/itau-jhsf-ban...      2
# 3      https://www.moneytimes.com.br/itau-unibanco-it...      2
# 5      https://www.moneytimes.com.br/kroton-faz-parce...      2
# 9      https://www.suno.com.br/noticias/itausa-lucro-...      2
# 15     https://www.suno.com.br/noticias/mesquita-itau...      2
# ...                                                  ...    ...
# 11932  https://www.moneytimes.com.br/btg-espera-ganha...      2
# 11934  https://www.suno.com.br/noticias/ibovespa-gued...      2
# 11942  https://www.moneytimes.com.br/3-acoes-de-banco...      2
# 11947  https://www.suno.com.br/noticias/banco-do-bras...      2
# 11955  https://www.moneytimes.com.br/em-ano-ruim-acoe...      2
#
# [2103 rows x 4 columns]

# %%
itub4.loc[(itub4['title'].str.contains('itau') == False) & (itub4['title'].str.contains('itub4') == False)]
# Out:
#                                                    title  \
# 19     bracher previdencia deve aprovada setembro eco...
# 41                bancos digitais miram credito veiculos
# 47                          o esperar acoes bancos <NUM>
# 61     bs2 compra fintech weel preve maior pais antec...
# 77     esta cedo demais analisar pesquisas segundo turno
# ...                                                  ...
# 11924  brf brfs3 cai <NUM> cento abertura mercado vej...
# 11932  btg espera ganhar clientes agentes negocio xp ...
# 11934  ibovespa opera ganhos perdas sustentado bancos...
# 11942  <NUM> acoes bancos brasileiros melhores ter lo...
# 11955  em ano ruim acoes bancos brasileiros podem sub...
#
#                                                     tags  \
# 19     ['Arena do Pavini', 'Candido Bracher', 'Econom...
# 41     ['Bancos', 'Bradesco', 'C6 Bank', 'Estadão Con...
# 47     ['Banco do Brasil', 'Bancos', 'Bradesco', 'Com...
# 61     ['Brasil', 'Cielo', 'Coronavírus', 'Crédito', ...
# 77     ['Eleições 2018', 'Fernando Haddad', 'Itaú Uni...
# ...                                                  ...
# 11924  ['Ações', 'Alpargatas', 'Bolsa', 'Bolsa de Val...
# 11932  ['Arena do Pavini', 'Bancos', 'BTG Pactual', '...
# 11934  ['Bradesco (BBDC3/BBDC4)', 'Braskem (BRKM3/BRK...
# 11942  ['Ações', 'Banco do Brasil', 'Bancos', 'Brades...
# 11955  ['Ações', 'Banco do Brasil', 'Bancos', 'Brades...
#
#                                                     link  label
# 19     https://www.moneytimes.com.br/bracher-previden...      2
# 41     https://www.moneytimes.com.br/bancos-digitais-...      2
# 47     https://www.moneytimes.com.br/o-que-esperar-da...      2
# 61     https://www.moneytimes.com.br/bs2-compra-finte...      2
# 77     https://www.moneytimes.com.br/esta-cedo-demais...      2
# ...                                                  ...    ...
# 11924  https://www.moneytimes.com.br/brf-brfs3-cai-ma...      2
# 11932  https://www.moneytimes.com.br/btg-espera-ganha...      2
# 11934  https://www.suno.com.br/noticias/ibovespa-gued...      2
# 11942  https://www.moneytimes.com.br/3-acoes-de-banco...      2
# 11955  https://www.moneytimes.com.br/em-ano-ruim-acoe...      2
#
# [890 rows x 4 columns]
