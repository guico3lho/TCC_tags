# %% [markdown]
# ## Packages and Assets

# %%
from wordcloud import WordCloud
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_preprocessed = pd.read_csv('../assets/data/splits/train/preprocessed.csv')
val_preprocessed = pd.read_csv('../assets/data/splits/val/preprocessed.csv')
test_preprocessed = pd.read_csv('../assets/data/splits/test/preprocessed.csv')
df_preprocessed = pd.concat([train_preprocessed, val_preprocessed, test_preprocessed])
df_preprocessed
# Out:
#                                                   title  \
# 0     vale decide desembolsar <NUM> bilhoes linhas c...
# 1     gasolina sobe quase <NUM> cento postos <NUM> m...
# 2        jair bolsonaro anuncia ministro defesa governo
# 3      senado votara nessa quarta novo marco saneamento
# 4     ibovespa opera acima <NUM> mil pontos nesta manha
# ...                                                 ...
# 1797  weg wege3 pagara milhoes jcp ameaca greve cami...
# 1798          vale renova mandato schvartsman dois anos
# 1799    petrobras confirma ipo br listagem novo mercado
# 1800  dolar abre queda <NUM> cento apos dados desemp...
# 1801       vale diz barragens tem plano acao emergencia
#
#                                                    tags  \
# 0     ['Coronavírus', 'Crédito', 'Empresas', 'Minera...
# 1     ['Brasil', 'Combustíveis', 'Economia', 'Empres...
# 2                        ['Jair Bolsonaro', 'Política']
# 3     ['Jair Bolsonaro', 'marco do saneamento', 'Sen...
# 4                                          ['ibovespa']
# ...                                                 ...
# 1797  ['Weg (WEGE3)', 'Magazine Luiza (MGLU3)', 'Oi ...
# 1798          ['Fabio Schvartsman', 'Mercados', 'Vale']
# 1799  ['BR Distribuidora', 'Empresas', 'IPO', 'Petro...
# 1800  ['bce', 'Desemprego', 'dólar', 'EUA', 'Tesouro...
# 1801              ['Minas Gerais', 'Mineração', 'Vale']
#
#                                                    link  label
# 0     https://www.moneytimes.com.br/vale-decide-dese...      2
# 1     https://www.moneytimes.com.br/gasolina-sobe-qu...      1
# 2     https://www.sunoresearch.com.br/noticias/jair-...      0
# 3     https://www.sunoresearch.com.br/noticias/senad...      0
# 4     https://www.sunoresearch.com.br/noticias/ibove...      0
# ...                                                 ...    ...
# 1797  https://www.suno.com.br/noticias/weg-wege3-div...      1
# 1798  https://www.moneytimes.com.br/vale-renova-mand...      2
# 1799  https://www.moneytimes.com.br/petrobras-confir...      1
# 1800  https://www.sunoresearch.com.br/noticias/dolar...      0
# 1801  https://www.moneytimes.com.br/vale-diz-que-sua...      2
#
# [18012 rows x 4 columns]

# %%
petr4 = df_preprocessed.loc[df_preprocessed['label'] == 1]
vale3 = df_preprocessed.loc[df_preprocessed['label'] == 2]
itub4 = df_preprocessed.loc[df_preprocessed['label'] == 3]
outras = df_preprocessed.loc[df_preprocessed['label'] == 0]

# %% [markdown]
# ## Functions

# %%
stopwords = ["da", "meu", "em", "voce", "de", "ao", "os", "<NUM>", "<num>", "num", "NUM", 'acoe', 'acoes', 'milhoe',' bilhoe', 'milhoes', 'cento', 'diz', 'bilhoes']

# %%
summary_petr4 = " ".join(str(s) for s in petr4['title'].values)
summary_vale3 = " ".join(str(s) for s in vale3['title'].values)
summary_itub4 = " ".join(str(s) for s in itub4['title'].values)
summary_outras = " ".join(str(s) for s in outras['title'].values)

# %% [markdown]
# ## PETR4

# %% [markdown]
# ### Wordcloud

# %%
wordcloud_petr4 = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_petr4)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_petr4)
plt.axis('off')
plt.title("Words related to PETR4")
plt.show()

# %% [markdown]
# ### See news that doesnt have the word "petrobras" or "petr4"

# %%
petr4
# Out:
#                                                   title  \
# 1     gasolina sobe quase <NUM> cento postos <NUM> m...
# 8     petrobras aprova cessao participacao campos pe...
# 9      mercado comeca precificar fortalecimento alckmin
# 10    petrobras perfura poco profundo historia brasi...
# 15    petrobras afirma oferta recompra titulos deve ...
# ...                                                 ...
# 1786  investimentos estatais federais caem <NUM> cen...
# 1793  petrobras sobe <NUM> cento balanco melhor espe...
# 1795  surto covid duas plataformas petrobras leva de...
# 1797  weg wege3 pagara milhoes jcp ameaca greve cami...
# 1799    petrobras confirma ipo br listagem novo mercado
#
#                                                    tags  \
# 1     ['Brasil', 'Combustíveis', 'Economia', 'Empres...
# 8     ['Combustíveis', 'Economia', 'Petrobras', 'Pet...
# 9     ['Eleições 2018', 'Geraldo Alckmin', 'Mercados...
# 10    ['Cidades', 'Combustíveis', 'Commodities', 'Em...
# 15    ['Combustíveis', 'Empresas', 'Petrobras', 'Pet...
# ...                                                 ...
# 1786  ['Eletrobras', 'Empresas', 'Governo Federal', ...
# 1793   ['Bolsa', 'Ibovespa', 'Petrobras', 'Resultados']
# 1795  ['Ações', 'Brasil', 'Coronavírus', 'Empresas',...
# 1797  ['Weg (WEGE3)', 'Magazine Luiza (MGLU3)', 'Oi ...
# 1799  ['BR Distribuidora', 'Empresas', 'IPO', 'Petro...
#
#                                                    link  label
# 1     https://www.moneytimes.com.br/gasolina-sobe-qu...      1
# 8     https://www.moneytimes.com.br/petrobras-aprova...      1
# 9     https://www.moneytimes.com.br/mercado-comeca-a...      1
# 10    https://www.moneytimes.com.br/petrobras-perfur...      1
# 15    https://www.moneytimes.com.br/petrobras-afirma...      1
# ...                                                 ...    ...
# 1786  https://www.moneytimes.com.br/investimentos-da...      1
# 1793  https://www.moneytimes.com.br/petrobras-sobe-m...      1
# 1795  https://www.moneytimes.com.br/surto-de-covid-e...      1
# 1797  https://www.suno.com.br/noticias/weg-wege3-div...      1
# 1799  https://www.moneytimes.com.br/petrobras-confir...      1
#
# [6113 rows x 4 columns]

# %%
petr4.loc[(petr4['title'].str.contains('petrobras') == False) & (petr4['title'].str.contains('petr4') == False)]
# Out:
#                                                   title  \
# 1     gasolina sobe quase <NUM> cento postos <NUM> m...
# 9      mercado comeca precificar fortalecimento alckmin
# 21    onda ipos brasil pode sofrer piora risco polit...
# 35         ibovespa fecha alta <NUM> cento <NUM> pontos
# 38    bolsonaro diz define semana extensao auxilio e...
# ...                                                 ...
# 1758  brasil trabalha politicas ficar refem alta pet...
# 1771  ibovespa futuro abre queda <NUM> cento juros f...
# 1774  ibovespa sobe <NUM> cento pressionado volatili...
# 1786  investimentos estatais federais caem <NUM> cen...
# 1797  weg wege3 pagara milhoes jcp ameaca greve cami...
#
#                                                    tags  \
# 1     ['Brasil', 'Combustíveis', 'Economia', 'Empres...
# 9     ['Eleições 2018', 'Geraldo Alckmin', 'Mercados...
# 21    ['Ações', 'B3', 'Brasil', 'CVM', 'Instagram', ...
# 35    ['Embraer (EMBR3)', 'Gafisa (GFSA3)', 'Ibovesp...
# 38    ['Auxílio Emergencial', 'Benefícios', 'Brasil'...
# ...                                                 ...
# 1758  ['Bento Albuquerque', 'Combustíveis', 'Economi...
# 1771  ['Copom', 'coronavírus', 'Estados Unidos (EUA)...
# 1774  ['Aliansce Sonae (ALSO3)', 'Banco do Brasil (B...
# 1786  ['Eletrobras', 'Empresas', 'Governo Federal', ...
# 1797  ['Weg (WEGE3)', 'Magazine Luiza (MGLU3)', 'Oi ...
#
#                                                    link  label
# 1     https://www.moneytimes.com.br/gasolina-sobe-qu...      1
# 9     https://www.moneytimes.com.br/mercado-comeca-a...      1
# 21    https://www.moneytimes.com.br/onda-de-ipos-no-...      1
# 35    https://www.suno.com.br/noticias/ibovespa-fech...      1
# 38    https://www.moneytimes.com.br/bolsonaro-diz-qu...      1
# ...                                                 ...    ...
# 1758  https://www.moneytimes.com.br/brasil-trabalha-...      1
# 1771  https://www.suno.com.br/noticias/ibovespa-futu...      1
# 1774  https://www.suno.com.br/noticias/ibovespa-sobe...      1
# 1786  https://www.moneytimes.com.br/investimentos-da...      1
# 1797  https://www.suno.com.br/noticias/weg-wege3-div...      1
#
# [1936 rows x 4 columns]

# %% [markdown]
# ## VALE3

# %% [markdown]
# ### WordCloud

# %%
wordcloud_vale3 = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_vale3)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_vale3)
plt.axis('off')
plt.title("Words related to VALE3")
plt.show()

# %% [markdown]
# ### See news that doesnt have the word "vale" or "vale3"

# %%
vale3
# Out:
#                                                   title  \
# 0     vale decide desembolsar <NUM> bilhoes linhas c...
# 12    minerio ferro segue negociacao paralisada feri...
# 16    pf preve novos indiciamentos tragedia brumadin...
# 17    agencia recomenda extincao barragens montante ...
# 20    em cpi exmenos diretor vale diz ter sido punid...
# ...                                                 ...
# 1785  mpf pode retomar acao <NUM> bilhoes contra sam...
# 1788  fibria weg abrem temporada balancos acoes ibov...
# 1791  lama barragem vale pode chegar foz rio paraope...
# 1798          vale renova mandato schvartsman dois anos
# 1801       vale diz barragens tem plano acao emergencia
#
#                                                    tags  \
# 0     ['Coronavírus', 'Crédito', 'Empresas', 'Minera...
# 12    ['China', 'Commodities', 'Investing.com', 'Min...
# 16    ['Meio Ambiente', 'Mineração', 'Tüv Süd', 'Vale']
# 17                    ['Empresas', 'Mineração', 'Vale']
# 20       ['Brumadinho', 'Justiça', 'Mineração', 'Vale']
# ...                                                 ...
# 1785  ['BHP Billiton', 'Brasil', 'Justiça', 'Minas G...
# 1788  ['Ações', 'Economia', 'Fibria', 'Ibovespa', 'L...
# 1791             ['Brumadinho', 'Minas Gerais', 'Vale']
# 1798          ['Fabio Schvartsman', 'Mercados', 'Vale']
# 1801              ['Minas Gerais', 'Mineração', 'Vale']
#
#                                                    link  label
# 0     https://www.moneytimes.com.br/vale-decide-dese...      2
# 12    https://www.moneytimes.com.br/minerio-de-ferro...      2
# 16    https://www.moneytimes.com.br/pf-preve-novos-i...      2
# 17    https://www.moneytimes.com.br/agencia-recomend...      2
# 20    https://www.moneytimes.com.br/em-cpi-ex-direto...      2
# ...                                                 ...    ...
# 1785  https://www.moneytimes.com.br/mpf-pode-retomar...      2
# 1788  https://www.moneytimes.com.br/fibria-e-weg-abr...      2
# 1791  https://www.moneytimes.com.br/lama-da-barragem...      2
# 1798  https://www.moneytimes.com.br/vale-renova-mand...      2
# 1801  https://www.moneytimes.com.br/vale-diz-que-sua...      2
#
# [3740 rows x 4 columns]

# %%
vale3.loc[(vale3['title'].str.contains('vale3') == False) & (vale3['title'].str.contains('vale') == False)]
# Out:
#                                                   title  \
# 12    minerio ferro segue negociacao paralisada feri...
# 16    pf preve novos indiciamentos tragedia brumadin...
# 17    agencia recomenda extincao barragens montante ...
# 32    defesa civil divulga plano casos risco outras ...
# 44    lojas renner opera perdas <NUM> cento empresa ...
# ...                                                 ...
# 1778  dividendos genial atualiza carteira marco espe...
# 1781  minerio ferro interrompe sequencia quedas avan...
# 1783  minerio ferro recua <NUM> cento bolsa chinesa ...
# 1785  mpf pode retomar acao <NUM> bilhoes contra sam...
# 1788  fibria weg abrem temporada balancos acoes ibov...
#
#                                                    tags  \
# 12    ['China', 'Commodities', 'Investing.com', 'Min...
# 16    ['Meio Ambiente', 'Mineração', 'Tüv Süd', 'Vale']
# 17                    ['Empresas', 'Mineração', 'Vale']
# 32               ['Brumadinho', 'Minas Gerais', 'Vale']
# 44    ['BTG Pactual', 'Comprar ou vender?', 'Lojas R...
# ...                                                 ...
# 1778  ['Ações', 'Alupar', 'Carteira Recomendada', 'D...
# 1781  ['China', 'Commodities', 'Mineração', 'Minério...
# 1783  ['China', 'Commodities', 'Internacional', 'Inv...
# 1785  ['BHP Billiton', 'Brasil', 'Justiça', 'Minas G...
# 1788  ['Ações', 'Economia', 'Fibria', 'Ibovespa', 'L...
#
#                                                    link  label
# 12    https://www.moneytimes.com.br/minerio-de-ferro...      2
# 16    https://www.moneytimes.com.br/pf-preve-novos-i...      2
# 17    https://www.moneytimes.com.br/agencia-recomend...      2
# 32    https://www.moneytimes.com.br/defesa-civil-div...      2
# 44    https://www.moneytimes.com.br/lojas-renner-ope...      2
# ...                                                 ...    ...
# 1778  https://www.moneytimes.com.br/dividendos-genia...      2
# 1781  https://www.moneytimes.com.br/minerio-de-ferro...      2
# 1783  https://www.moneytimes.com.br/minerio-de-ferro...      2
# 1785  https://www.moneytimes.com.br/mpf-pode-retomar...      2
# 1788  https://www.moneytimes.com.br/fibria-e-weg-abr...      2
#
# [1556 rows x 4 columns]

# %% [markdown]
# ## ITUB4

# %% [markdown]
# ### WordCloud

# %%
wordcloud_itub4 = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_itub4)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_itub4)
plt.axis('off')
plt.title("Words related to ITU4")
plt.show()

# %% [markdown]
# ### See news that doesnt have the word "itau" or "itub4"

# %%
itub4
# Out:
#                                                   title  \
# 5      coinbase planeja ipo pode valer dois itaus itub4
# 25    ibovespa abre alta <NUM> cento gpa pcar3 dispa...
# 53    reacao bancos exagerada diz xp sobre aumento i...
# 75    itau adquire corretora verbank securities para...
# 78               itau anuncia captacao <NUM> bilhao eua
# ...                                                 ...
# 1743  dividendos banco brasil bbas3 cenario ruim var...
# 1750  irb brasil acumula alta <NUM> cento desde ofer...
# 1763  itau itub4 piora previsoes brasil ve selic <NU...
# 1775  banco brasil bbas3 itau itub4 copel cple6 paga...
# 1777  itau lanca cartao virtual pagamento servicos a...
#
#                                                    tags  \
# 5     ['Banco do Brasil (BBAS3)', 'Bradesco (BBDC3/B...
# 25    ['Ibovespa', 'Assaí (ASAI3)', 'Grupo Pão de Aç...
# 53    ['bancos', 'Bradesco (BBDC3/BBDC4)', 'Especial...
# 75    ['Ações', 'Bancos', 'Corretoras', 'Empresas', ...
# 78    ['Banco Central (BC)', 'Itaú Unibanco (ITUB3/I...
# ...                                                 ...
# 1743  ['Magazine Luiza (MGLU3)', 'americanas S.A (AM...
# 1750  ['BB Seguridade', 'IRB', 'Itaú Unibanco', 'Mer...
# 1763  ['dólar', 'dólar', 'Especialistas', 'IPCA', 'I...
# 1775  ['Banco do Brasil (BBAS3)', 'BB Seguridade (BB...
# 1777  ['Bancos', 'Cartão de Crédito', 'Empresas', 'I...
#
#                                                    link  label
# 5     https://www.suno.com.br/noticias/coinbase-crip...      3
# 25    https://www.suno.com.br/noticias/ibovespa-gpa-...      3
# 53    https://www.suno.com.br/noticias/reacao-bancos...      3
# 75    https://www.moneytimes.com.br/itau-adquire-cor...      3
# 78    https://www.suno.com.br/noticias/itau-anuncia-...      3
# ...                                                 ...    ...
# 1743  https://www.suno.com.br/noticias/banco-do-bras...      3
# 1750  https://www.moneytimes.com.br/irb-brasil-acumu...      3
# 1763  https://www.suno.com.br/noticias/itau-itub4-pr...      3
# 1775  https://www.suno.com.br/noticias/mais-lidas-bb...      3
# 1777  https://www.moneytimes.com.br/itau-lanca-carta...      3
#
# [2159 rows x 4 columns]

# %%
itub4.loc[(itub4['title'].str.contains('itau') == False) & (itub4['title'].str.contains('itub4') == False)]
# Out:
#                                                   title  \
# 25    ibovespa abre alta <NUM> cento gpa pcar3 dispa...
# 53    reacao bancos exagerada diz xp sobre aumento i...
# 103   cvc estreia cashback parceria csu lancara mark...
# 108                              chama max defeito voce
# 110   <NUM> acoes bancos brasileiros melhores ter lo...
# ...                                                 ...
# 1708  plataforma erp omie compra fintech linker <NUM...
# 1719  ibovespa fecha alta termina perto <NUM> mil po...
# 1736  abertura capital banco bmg pode levantar <NUM>...
# 1743  dividendos banco brasil bbas3 cenario ruim var...
# 1750  irb brasil acumula alta <NUM> cento desde ofer...
#
#                                                    tags  \
# 25    ['Ibovespa', 'Assaí (ASAI3)', 'Grupo Pão de Aç...
# 53    ['bancos', 'Bradesco (BBDC3/BBDC4)', 'Especial...
# 103   ['Bancos', 'CSU Cardsystem', 'CVC Brasil', 'Em...
# 108   ['Bancos', 'Bradesco', 'Colunista Empiricus', ...
# 110   ['Ações', 'Banco do Brasil', 'Bancos', 'Brades...
# ...                                                 ...
# 1708  ['Ações', 'Empresas', 'Fintech', 'Itaú Unibanc...
# 1719  ['Bradesco BBI', 'BTG Pactual', 'Burger King',...
# 1736  ['Banco Inter (BIDI11/BIDI4/BIDI3)', 'IPO (Ofe...
# 1743  ['Magazine Luiza (MGLU3)', 'americanas S.A (AM...
# 1750  ['BB Seguridade', 'IRB', 'Itaú Unibanco', 'Mer...
#
#                                                    link  label
# 25    https://www.suno.com.br/noticias/ibovespa-gpa-...      3
# 53    https://www.suno.com.br/noticias/reacao-bancos...      3
# 103   https://www.moneytimes.com.br/cvc-estreia-e-ca...      3
# 108   https://www.moneytimes.com.br/chama-o-max-defe...      3
# 110   https://www.moneytimes.com.br/3-acoes-de-banco...      3
# ...                                                 ...    ...
# 1708  https://www.moneytimes.com.br/plataforma-de-er...      3
# 1719  https://www.moneytimes.com.br/ibovespa-fecha-e...      3
# 1736  https://www.suno.com.br/noticias/ipo-bmg-levan...      3
# 1743  https://www.suno.com.br/noticias/banco-do-bras...      3
# 1750  https://www.moneytimes.com.br/irb-brasil-acumu...      3
#
# [915 rows x 4 columns]

# %% [markdown]
# ## Outras

# %%
wordcloud_outras = WordCloud(collocations=False, stopwords=stopwords, background_color='white', width=1600, height=800).generate(summary_outras)
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud_outras)
plt.axis('off')
plt.title("Words related to Outras")
plt.show()
